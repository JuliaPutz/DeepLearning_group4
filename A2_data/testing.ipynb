# %%
import os
from collections import namedtuple

import cv2
import numpy as np
import torch

# A 2D vector. Used in Fn as an evaluation point.
Vec2 = namedtuple('Vec2', ['x1', 'x2'])

class AutogradFn(torch.autograd.Function):
    '''
    This class wraps a Fn instance to make it compatible with PyTorch optimizers
    '''
    @staticmethod
    def forward(ctx, fn, loc):
        ctx.fn = fn
        ctx.save_for_backward(loc)
        value = fn(Vec2(loc[0].item(), loc[1].item()))
        return torch.tensor(value)

    @staticmethod
    def backward(ctx, grad_output):
        fn = ctx.fn
        loc, = ctx.saved_tensors
        grad = fn.grad(Vec2(loc[0].item(), loc[1].item()))
        return None, torch.tensor([grad.x1, grad.x2]) * grad_output


def load_image(fpath: str) -> np.ndarray:
    '''
    Loads a 2D function from a PNG file and normalizes it to the interval [0, 1]
    Raises FileNotFoundError if the file does not exist.
    '''

    # not 100% sure is 2D Function a numpy array?
    if os.path.exists(fpath):
        image = cv2.imread(fpath, cv2.IMREAD_GRAYSCALE)
        # output dtype needs to be float not int to properly represent image
        # in range [0, 1]
        image_normalized = cv2.normalize(image, None, 0, 1.0, cv2.NORM_MINMAX, dtype=cv2.CV_32F)

        return image_normalized
    else:
        raise FileNotFoundError(f"Path: {fpath} not found")
    

class Fn:
    '''
    A 2D function evaluated on a grid.
    '''

    def __init__(self, fn: np.ndarray, eps: float):
        '''
        Ctor that assigns function data fn and step size eps for numerical differentiation
        '''

        self.fn = fn
        self.eps = eps

    def visualize(self) -> np.ndarray:
        '''
        Return a visualization of the function as a color image. Use e.g. cv2.applyColorMap.
        Use the result to visualize the progress of gradient descent.
        '''

        # TODO implement
        # ?? How does this work with normalized input with dtype CV_32F ??
        # this might be a workaround, looks right at least
        vis = cv2.applyColorMap(np.uint8(self.fn * 255), cv2.COLORMAP_RAINBOW)

        return vis

    def __call__(self, loc: Vec2) -> float:
        '''
        Evaluate the function at location loc.
        Raises ValueError if loc is out of bounds.
        '''

        # You can simply round and map to integers. If so, make sure not to set eps and learning_rate too low
        # Alternatively, you can implement some form of interpolation (for example bilinear)
        sx1_rounded = round(loc[0])
        sx2_rounded = round(loc[1])

        # raise Value error if loc is out of bounds 
        # values of loc need to be rounded first to be able to check that
        if sx1_rounded > self.fn.shape[0] or sx2_rounded > self.fn.shape[1]:
            raise ValueError("loc is out of bounds")

        return self.fn[sx2_rounded, sx1_rounded]
        

    def grad(self, loc: Vec2) -> Vec2:
        '''
        Compute the numerical gradient of the function at location loc, using the given epsilon.
        Raises ValueError if loc is out of bounds of fn or if eps <= 0.
        '''

        # implemented
        # are errors correct?
        if loc[0] > self.fn.shape[0] or loc[1] > self.fn.shape[1]:
            raise ValueError("loc is out of bounds")
        elif self.eps <= 0:
            raise ValueError("eps has to be > 0")
        elif round(loc[0] + self.eps) > self.fn.shape[0] or round(loc[1] + self.eps) > self.fn.shape[1]:
            raise ValueError("eps + loc is out of bounds")
        else:
            position_loc = self(loc)
            position_plus_x1 = self(Vec2(loc[0] + self.eps, loc[1]))
            position_plus_x2 = self(Vec2(loc[0], loc[1] + self.eps))

            num_gradient_x1 = (position_plus_x1 - position_loc) / self.eps
            num_gradient_x2 = (position_plus_x2 - position_loc) / self.eps

        return Vec2(num_gradient_x1, num_gradient_x2)

# %%
fpath = r"fn/camel3.png"
sx1 = 200.
sx2 = 200.
eps = 10.
learning_rate = 10.
beta = 0
nesterov = False

# Init
image_fn = load_image(fpath)
fn = Fn(image_fn, eps)
vis = fn.visualize()

# PyTorch uses tensors which are very similar to numpy arrays but hold additional values such as gradients
loc = torch.tensor([sx1, sx2], requires_grad=True)
optimizer = torch.optim.SGD([loc], lr=learning_rate, momentum=beta, nesterov=nesterov)
prev_loc = loc
print(f"Starting point: {prev_loc}")
iteration = 0

# Find a minimum in fn using a PyTorch optimizer
# See https://pytorch.org/docs/stable/optim.html for how to use optimizers
while True:
    # Visualize each iteration by drawing on vis using e.g. cv2.line()
    # Find a suitable termination condition and break out of loop once done

    # This returns the value of the function fn at location loc.
    # Since we are trying to find a minimum of the function this acts as a loss value.
    loss = AutogradFn.apply(fn, loc)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print(loss)

    # calculate starting and end point of line representing the gradient
    new_x1 = loc.grad[0].item() + loc[0].item()
    new_x2 = loc.grad[1].item() + loc[1].item()

    start = (round(prev_loc[0].item()), round(prev_loc[1].item()))
    end = (round(new_x1),  round(new_x2))
    
    cv2.line(vis, start, end, [0, 0, 0], 2)
    cv2.imshow('Progress', vis)
    cv2.waitKey(50)  # 20 fps, tune according to your liking

    if loc.grad[0].item() == 0. and loc.grad[1].item() == 0.:
        print(loc.grad)
        print(f"reached local min")
        break
    elif iteration > 1000:
        print("reached max iterations")
        break

    iteration += 1
    prev_loc = torch.tensor([new_x1, new_x2])

print(f"Needed iterations: {iteration}")
# Out:
# Starting point: tensor([200., 200.], requires_grad=True)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4118, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4078, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4039, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.4000, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3961, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3922, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# tensor(0.3882, grad_fn=<AutogradFnBackward>)
# reached max iterations
# Needed iterations: 1001
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ------

# %%
import os
from collections import namedtuple

import cv2
import numpy as np
import torch

# %%
fpath = r"fn/camel3.png"

# %%
image = cv2.imread(fpath, cv2.IMREAD_GRAYSCALE)

norm = np.zeros(image.shape)
img_normalized = cv2.normalize(image, 
                               norm, 
                               alpha = 0.0, 
                               beta = 1.0, 
                               norm_type = cv2.NORM_MINMAX,
                               dtype = cv2.CV_32F)

vis = cv2.applyColorMap(np.uint8(img_normalized * 255), cv2.COLORMAP_RAINBOW)

cv2.imshow('normalized image', vis)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
np.uint8(img_normalized * 255)
# Out:
# array([[255, 255, 254, ...,  48,  48,  48],
#        [255, 254, 253, ...,  47,  47,  47],
#        [254, 253, 253, ...,  47,  47,  47],
#        ...,
#        [ 47,  47,  47, ..., 253, 253, 254],
#        [ 47,  47,  47, ..., 253, 254, 255],
#        [ 48,  48,  48, ..., 254, 255, 255]], dtype=uint8)

# %%
np.equal(image, np.uint8(img_normalized * 255))[True]
# Out:
# array([[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]]])

# %% [markdown]
# ## Start optimizer_2d.py

# %%
Vec2 = namedtuple('Vec2', ['x1', 'x2'])

# %%
class AutogradFn(torch.autograd.Function):
    '''
    This class wraps a Fn instance to make it compatible with PyTorch optimizers
    '''
    @staticmethod
    def forward(ctx, fn, loc):
        ctx.fn = fn
        ctx.save_for_backward(loc)
        value = fn(Vec2(loc[0].item(), loc[1].item()))
        return torch.tensor(value)

    @staticmethod
    def backward(ctx, grad_output):
        fn = ctx.fn
        loc, = ctx.saved_tensors
        grad = fn.grad(Vec2(loc[0].item(), loc[1].item()))
        return None, torch.tensor([grad.x1, grad.x2]) * grad_output

# %%
def load_image(fpath: str) -> np.ndarray:
    '''
    Loads a 2D function from a PNG file and normalizes it to the interval [0, 1]
    Raises FileNotFoundError if the file does not exist.
    '''

    # not 100% sure is 2D Function a numpy array?
    if os.path.exists(fpath):
        image = cv2.imread(fpath, cv2.IMREAD_GRAYSCALE)
        image_normalized = cv2.normalize(image, None, 0, 1.0, cv2.NORM_MINMAX, dtype=cv2.CV_32F)

        return image_normalized
    else:
        raise FileNotFoundError(f"Path: {fpath} not found")

# %%
class Fn:
    '''
    A 2D function evaluated on a grid.
    '''

    def __init__(self, fn: np.ndarray, eps: float):
        '''
        Ctor that assigns function data fn and step size eps for numerical differentiation
        '''

        self.fn = fn
        self.eps = eps

    def visualize(self) -> np.ndarray:
        '''
        Return a visualization of the function as a color image. Use e.g. cv2.applyColorMap.
        Use the result to visualize the progress of gradient descent.
        '''

        # TODO implement
        # ?? How does this work with normalized input with dtype CV_32F ??
        # this might be a workaround, looks right at least
        vis = cv2.applyColorMap(np.uint8(self.fn * 255), cv2.COLORMAP_RAINBOW)

        return vis

    def __call__(self, loc: Vec2) -> float:
        '''
        Evaluate the function at location loc.
        Raises ValueError if loc is out of bounds.
        '''

        # You can simply round and map to integers. If so, make sure not to set eps and learning_rate too low
        # Alternatively, you can implement some form of interpolation (for example bilinear)
        sx1_rounded = round(loc[0])
        sx2_rounded = round(loc[1])

        # raise Value error if loc is out of bounds 
        # values of loc need to be rounded first to be able to check that
        if sx1_rounded > self.fn.shape[0] or sx2_rounded > self.fn.shape[1]:
            raise ValueError("loc is out of bounds")

        return self.fn[sx1_rounded, sx2_rounded]
        

    def grad(self, loc: Vec2) -> Vec2:
        '''
        Compute the numerical gradient of the function at location loc, using the given epsilon.
        Raises ValueError if loc is out of bounds of fn or if eps <= 0.
        '''

        # TODO 
        if loc[0] > self.fn.shape[0] or loc[1] > self.fn.shape[1]:
            raise ValueError("loc is out of bounds")
        elif self.eps <= 0:
            raise ValueError("eps has to be > 0")
        elif loc[0] + self.eps > self.fn.shape[0] or loc[1] + self.eps > self.fn.shape[1]:
            raise ValueError("eps + loc is out of bounds")
        else:
            position_loc = self(loc)
            position_plus_x1 = self(Vec2(loc[0] + self.eps, loc[1]))
            print(f"Position x1 + eps {loc[0] + self.eps}")
            print(f"value + eps: {position_plus_x1}")
            position_plus_x2 = self(Vec2(loc[0], loc[1] + self.eps))
            print(f"position x2 + eps {loc[1] + self.eps}")
            print(f"value x2 + eps {position_plus_x2}")

            num_gradient_x1 = (position_plus_x1 - position_loc) / self.eps
            num_gradient_x2 = (position_plus_x2 - position_loc) / self.eps


        return Vec2(num_gradient_x1, num_gradient_x2)

# %%
#parser = argparse.ArgumentParser(description='Perform gradient descent on a 2D function.')
#parser.add_argument('fpath', help='Path to a PNG file encoding the function')
#parser.add_argument('sx1', type=float, help='Initial value of the first argument')
#parser.add_argument('sx2', type=float, help='Initial value of the second argument')
#parser.add_argument('--eps', type=float, default=1.0, help='Epsilon for computing numeric gradients')
#parser.add_argument('--learning_rate', type=float, default=10.0, help='Learning rate')
#parser.add_argument('--beta', type=float, default=0, help='Beta parameter of momentum (0 = no momentum)')
#parser.add_argument('--nesterov', action='store_true', help='Use Nesterov momentum')
#args = parser.parse_args()

fpath = r"fn/camel3.png"
sx1 = 900.
sx2 = 400.
eps = 10.
learning_rate = 10.0
beta = 0
nesterov = False

# %%
image_fn = load_image(fpath)
fn = Fn(image_fn, eps)
vis = fn.visualize()

# %%
image_fn.shape
# Out:
# (1000, 1000)

# %%
cv2.imshow('Progress', vis)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# PyTorch uses tensors which are very similar to numpy arrays but hold additional values such as gradients
loc = torch.tensor([sx1, sx2], requires_grad=True)
optimizer = torch.optim.SGD([loc], lr=learning_rate, momentum=beta, nesterov=nesterov)

# %%
fn(Vec2(900., 400.))
# Out:
# 0.054901965

# %%
while True:
    # Visualize each iteration by drawing on vis using e.g. cv2.line()
    # Find a suitable termination condition and break out of loop once done

    # This returns the value of the function fn at location loc.
    # Since we are trying to find a minimum of the function this acts as a loss value.
    loss = AutogradFn.apply(fn, loc)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    print(loss, loc.grad)

    start = (round(loc[0].item()), round(loc[1].item()))
    end = (round(loc.grad[0].item() * 100000) + round(loc[0].item()),  round(loc.grad[1].item()* 100000) + round(loc[1].item()))
    
    cv2.line(vis, start, end, [0, 255, 0], 2) 

    cv2.imshow('Progress', vis)
    cv2.waitKey(50)  # 20 fps, tune according to your liking

    if loc.grad[0].item() == 0. and loc.grad[1].item() == 0.:
        break
# Out:
# Position x1 + eps 910.0
# value + eps: 0.05098039656877518
# position x2 + eps 410.0
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.00390625
# value + eps: 0.05098039656877518
# position x2 + eps 409.9960632324219
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.0078125
# value + eps: 0.05098039656877518
# position x2 + eps 409.99212646484375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.01171875
# value + eps: 0.05098039656877518
# position x2 + eps 409.9881896972656
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.015625
# value + eps: 0.05098039656877518
# position x2 + eps 409.9842529296875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.01953125
# value + eps: 0.05098039656877518
# position x2 + eps 409.9803161621094
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.0234375
# value + eps: 0.05098039656877518
# position x2 + eps 409.97637939453125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.02734375
# value + eps: 0.05098039656877518
# position x2 + eps 409.9724426269531
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.03125
# value + eps: 0.05098039656877518
# position x2 + eps 409.968505859375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.03515625
# value + eps: 0.05098039656877518
# position x2 + eps 409.9645690917969
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.0390625
# value + eps: 0.05098039656877518
# position x2 + eps 409.96063232421875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.04296875
# value + eps: 0.05098039656877518
# position x2 + eps 409.9566955566406
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.046875
# value + eps: 0.05098039656877518
# position x2 + eps 409.9527587890625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.05078125
# value + eps: 0.05098039656877518
# position x2 + eps 409.9488220214844
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.0546875
# value + eps: 0.05098039656877518
# position x2 + eps 409.94488525390625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.05859375
# value + eps: 0.05098039656877518
# position x2 + eps 409.9409484863281
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.0625
# value + eps: 0.05098039656877518
# position x2 + eps 409.93701171875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.06640625
# value + eps: 0.05098039656877518
# position x2 + eps 409.9330749511719
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.0703125
# value + eps: 0.05098039656877518
# position x2 + eps 409.92913818359375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.07421875
# value + eps: 0.05098039656877518
# position x2 + eps 409.9252014160156
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.078125
# value + eps: 0.05098039656877518
# position x2 + eps 409.9212646484375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.08203125
# value + eps: 0.05098039656877518
# position x2 + eps 409.9173278808594
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.0859375
# value + eps: 0.05098039656877518
# position x2 + eps 409.91339111328125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.08984375
# value + eps: 0.05098039656877518
# position x2 + eps 409.9094543457031
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.09375
# value + eps: 0.05098039656877518
# position x2 + eps 409.905517578125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.09765625
# value + eps: 0.05098039656877518
# position x2 + eps 409.9015808105469
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.1015625
# value + eps: 0.05098039656877518
# position x2 + eps 409.89764404296875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.10546875
# value + eps: 0.05098039656877518
# position x2 + eps 409.8937072753906
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.109375
# value + eps: 0.05098039656877518
# position x2 + eps 409.8897705078125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.11328125
# value + eps: 0.05098039656877518
# position x2 + eps 409.8858337402344
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.1171875
# value + eps: 0.05098039656877518
# position x2 + eps 409.88189697265625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.12109375
# value + eps: 0.05098039656877518
# position x2 + eps 409.8779602050781
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.125
# value + eps: 0.05098039656877518
# position x2 + eps 409.8740234375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.12890625
# value + eps: 0.05098039656877518
# position x2 + eps 409.8700866699219
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.1328125
# value + eps: 0.05098039656877518
# position x2 + eps 409.86614990234375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.13671875
# value + eps: 0.05098039656877518
# position x2 + eps 409.8622131347656
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.140625
# value + eps: 0.05098039656877518
# position x2 + eps 409.8582763671875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.14453125
# value + eps: 0.05098039656877518
# position x2 + eps 409.8543395996094
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.1484375
# value + eps: 0.05098039656877518
# position x2 + eps 409.85040283203125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.15234375
# value + eps: 0.05098039656877518
# position x2 + eps 409.8464660644531
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.15625
# value + eps: 0.05098039656877518
# position x2 + eps 409.842529296875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.16015625
# value + eps: 0.05098039656877518
# position x2 + eps 409.8385925292969
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.1640625
# value + eps: 0.05098039656877518
# position x2 + eps 409.83465576171875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.16796875
# value + eps: 0.05098039656877518
# position x2 + eps 409.8307189941406
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.171875
# value + eps: 0.05098039656877518
# position x2 + eps 409.8267822265625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.17578125
# value + eps: 0.05098039656877518
# position x2 + eps 409.8228454589844
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.1796875
# value + eps: 0.05098039656877518
# position x2 + eps 409.81890869140625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.18359375
# value + eps: 0.05098039656877518
# position x2 + eps 409.8149719238281
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.1875
# value + eps: 0.05098039656877518
# position x2 + eps 409.81103515625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.19140625
# value + eps: 0.05098039656877518
# position x2 + eps 409.8070983886719
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.1953125
# value + eps: 0.05098039656877518
# position x2 + eps 409.80316162109375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.19921875
# value + eps: 0.05098039656877518
# position x2 + eps 409.7992248535156
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.203125
# value + eps: 0.05098039656877518
# position x2 + eps 409.7952880859375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.20703125
# value + eps: 0.05098039656877518
# position x2 + eps 409.7913513183594
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.2109375
# value + eps: 0.05098039656877518
# position x2 + eps 409.78741455078125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.21484375
# value + eps: 0.05098039656877518
# position x2 + eps 409.7834777832031
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.21875
# value + eps: 0.05098039656877518
# position x2 + eps 409.779541015625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.22265625
# value + eps: 0.05098039656877518
# position x2 + eps 409.7756042480469
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.2265625
# value + eps: 0.05098039656877518
# position x2 + eps 409.77166748046875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.23046875
# value + eps: 0.05098039656877518
# position x2 + eps 409.7677307128906
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.234375
# value + eps: 0.05098039656877518
# position x2 + eps 409.7637939453125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.23828125
# value + eps: 0.05098039656877518
# position x2 + eps 409.7598571777344
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.2421875
# value + eps: 0.05098039656877518
# position x2 + eps 409.75592041015625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.24609375
# value + eps: 0.05098039656877518
# position x2 + eps 409.7519836425781
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.25
# value + eps: 0.05098039656877518
# position x2 + eps 409.748046875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.25390625
# value + eps: 0.05098039656877518
# position x2 + eps 409.7441101074219
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.2578125
# value + eps: 0.05098039656877518
# position x2 + eps 409.74017333984375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.26171875
# value + eps: 0.05098039656877518
# position x2 + eps 409.7362365722656
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.265625
# value + eps: 0.05098039656877518
# position x2 + eps 409.7322998046875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.26953125
# value + eps: 0.05098039656877518
# position x2 + eps 409.7283630371094
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.2734375
# value + eps: 0.05098039656877518
# position x2 + eps 409.72442626953125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.27734375
# value + eps: 0.05098039656877518
# position x2 + eps 409.7204895019531
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.28125
# value + eps: 0.05098039656877518
# position x2 + eps 409.716552734375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.28515625
# value + eps: 0.05098039656877518
# position x2 + eps 409.7126159667969
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.2890625
# value + eps: 0.05098039656877518
# position x2 + eps 409.70867919921875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.29296875
# value + eps: 0.05098039656877518
# position x2 + eps 409.7047424316406
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.296875
# value + eps: 0.05098039656877518
# position x2 + eps 409.7008056640625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.30078125
# value + eps: 0.05098039656877518
# position x2 + eps 409.6968688964844
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.3046875
# value + eps: 0.05098039656877518
# position x2 + eps 409.69293212890625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.30859375
# value + eps: 0.05098039656877518
# position x2 + eps 409.6889953613281
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.3125
# value + eps: 0.05098039656877518
# position x2 + eps 409.68505859375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.31640625
# value + eps: 0.05098039656877518
# position x2 + eps 409.6811218261719
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.3203125
# value + eps: 0.05098039656877518
# position x2 + eps 409.67718505859375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.32421875
# value + eps: 0.05098039656877518
# position x2 + eps 409.6732482910156
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.328125
# value + eps: 0.05098039656877518
# position x2 + eps 409.6693115234375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.33203125
# value + eps: 0.05098039656877518
# position x2 + eps 409.6653747558594
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.3359375
# value + eps: 0.05098039656877518
# position x2 + eps 409.66143798828125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.33984375
# value + eps: 0.05098039656877518
# position x2 + eps 409.6575012207031
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.34375
# value + eps: 0.05098039656877518
# position x2 + eps 409.653564453125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.34765625
# value + eps: 0.05098039656877518
# position x2 + eps 409.6496276855469
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.3515625
# value + eps: 0.05098039656877518
# position x2 + eps 409.64569091796875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.35546875
# value + eps: 0.05098039656877518
# position x2 + eps 409.6417541503906
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.359375
# value + eps: 0.05098039656877518
# position x2 + eps 409.6378173828125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.36328125
# value + eps: 0.05098039656877518
# position x2 + eps 409.6338806152344
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.3671875
# value + eps: 0.05098039656877518
# position x2 + eps 409.62994384765625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.37109375
# value + eps: 0.05098039656877518
# position x2 + eps 409.6260070800781
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.375
# value + eps: 0.05098039656877518
# position x2 + eps 409.6220703125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.37890625
# value + eps: 0.05098039656877518
# position x2 + eps 409.6181335449219
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.3828125
# value + eps: 0.05098039656877518
# position x2 + eps 409.61419677734375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.38671875
# value + eps: 0.05098039656877518
# position x2 + eps 409.6102600097656
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.390625
# value + eps: 0.05098039656877518
# position x2 + eps 409.6063232421875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.39453125
# value + eps: 0.05098039656877518
# position x2 + eps 409.6023864746094
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.3984375
# value + eps: 0.05098039656877518
# position x2 + eps 409.59844970703125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.40234375
# value + eps: 0.05098039656877518
# position x2 + eps 409.5945129394531
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.40625
# value + eps: 0.05098039656877518
# position x2 + eps 409.590576171875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.41015625
# value + eps: 0.05098039656877518
# position x2 + eps 409.5866394042969
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.4140625
# value + eps: 0.05098039656877518
# position x2 + eps 409.58270263671875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.41796875
# value + eps: 0.05098039656877518
# position x2 + eps 409.5787658691406
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.421875
# value + eps: 0.05098039656877518
# position x2 + eps 409.5748291015625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.42578125
# value + eps: 0.05098039656877518
# position x2 + eps 409.5708923339844
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.4296875
# value + eps: 0.05098039656877518
# position x2 + eps 409.56695556640625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.43359375
# value + eps: 0.05098039656877518
# position x2 + eps 409.5630187988281
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.4375
# value + eps: 0.05098039656877518
# position x2 + eps 409.55908203125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.44140625
# value + eps: 0.05098039656877518
# position x2 + eps 409.5551452636719
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.4453125
# value + eps: 0.05098039656877518
# position x2 + eps 409.55120849609375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.44921875
# value + eps: 0.05098039656877518
# position x2 + eps 409.5472717285156
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.453125
# value + eps: 0.05098039656877518
# position x2 + eps 409.5433349609375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.45703125
# value + eps: 0.05098039656877518
# position x2 + eps 409.5393981933594
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.4609375
# value + eps: 0.05098039656877518
# position x2 + eps 409.53546142578125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.46484375
# value + eps: 0.05098039656877518
# position x2 + eps 409.5315246582031
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.46875
# value + eps: 0.05098039656877518
# position x2 + eps 409.527587890625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.47265625
# value + eps: 0.05098039656877518
# position x2 + eps 409.5236511230469
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.4765625
# value + eps: 0.05098039656877518
# position x2 + eps 409.51971435546875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.48046875
# value + eps: 0.05098039656877518
# position x2 + eps 409.5157775878906
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.484375
# value + eps: 0.05098039656877518
# position x2 + eps 409.5118408203125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.48828125
# value + eps: 0.05098039656877518
# position x2 + eps 409.5079040527344
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.4921875
# value + eps: 0.05098039656877518
# position x2 + eps 409.50396728515625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.49609375
# value + eps: 0.05098039656877518
# position x2 + eps 409.5000305175781
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.5
# value + eps: 0.05098039656877518
# position x2 + eps 409.49609375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 409.4921569824219
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.5078125
# value + eps: 0.05098039656877518
# position x2 + eps 409.48822021484375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.51171875
# value + eps: 0.05098039656877518
# position x2 + eps 409.4842834472656
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.515625
# value + eps: 0.05098039656877518
# position x2 + eps 409.4803466796875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.51953125
# value + eps: 0.05098039656877518
# position x2 + eps 409.4764099121094
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.5234375
# value + eps: 0.05098039656877518
# position x2 + eps 409.47247314453125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.52734375
# value + eps: 0.05098039656877518
# position x2 + eps 409.4685363769531
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.53125
# value + eps: 0.05098039656877518
# position x2 + eps 409.464599609375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.53515625
# value + eps: 0.05098039656877518
# position x2 + eps 409.4606628417969
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.5390625
# value + eps: 0.05098039656877518
# position x2 + eps 409.45672607421875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.54296875
# value + eps: 0.05098039656877518
# position x2 + eps 409.4527893066406
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.546875
# value + eps: 0.05098039656877518
# position x2 + eps 409.4488525390625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.55078125
# value + eps: 0.05098039656877518
# position x2 + eps 409.4449157714844
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.5546875
# value + eps: 0.05098039656877518
# position x2 + eps 409.44097900390625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.55859375
# value + eps: 0.05098039656877518
# position x2 + eps 409.4370422363281
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.5625
# value + eps: 0.05098039656877518
# position x2 + eps 409.43310546875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.56640625
# value + eps: 0.05098039656877518
# position x2 + eps 409.4291687011719
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.5703125
# value + eps: 0.05098039656877518
# position x2 + eps 409.42523193359375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.57421875
# value + eps: 0.05098039656877518
# position x2 + eps 409.4212951660156
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.578125
# value + eps: 0.05098039656877518
# position x2 + eps 409.4173583984375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.58203125
# value + eps: 0.05098039656877518
# position x2 + eps 409.4134216308594
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.5859375
# value + eps: 0.05098039656877518
# position x2 + eps 409.40948486328125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.58984375
# value + eps: 0.05098039656877518
# position x2 + eps 409.4055480957031
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.59375
# value + eps: 0.05098039656877518
# position x2 + eps 409.401611328125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.59765625
# value + eps: 0.05098039656877518
# position x2 + eps 409.3976745605469
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.6015625
# value + eps: 0.05098039656877518
# position x2 + eps 409.39373779296875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.60546875
# value + eps: 0.05098039656877518
# position x2 + eps 409.3898010253906
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.609375
# value + eps: 0.05098039656877518
# position x2 + eps 409.3858642578125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.61328125
# value + eps: 0.05098039656877518
# position x2 + eps 409.3819274902344
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.6171875
# value + eps: 0.05098039656877518
# position x2 + eps 409.37799072265625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.62109375
# value + eps: 0.05098039656877518
# position x2 + eps 409.3740539550781
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.625
# value + eps: 0.05098039656877518
# position x2 + eps 409.3701171875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.62890625
# value + eps: 0.05098039656877518
# position x2 + eps 409.3661804199219
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.6328125
# value + eps: 0.05098039656877518
# position x2 + eps 409.36224365234375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.63671875
# value + eps: 0.05098039656877518
# position x2 + eps 409.3583068847656
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.640625
# value + eps: 0.05098039656877518
# position x2 + eps 409.3543701171875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.64453125
# value + eps: 0.05098039656877518
# position x2 + eps 409.3504333496094
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.6484375
# value + eps: 0.05098039656877518
# position x2 + eps 409.34649658203125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.65234375
# value + eps: 0.05098039656877518
# position x2 + eps 409.3425598144531
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.65625
# value + eps: 0.05098039656877518
# position x2 + eps 409.338623046875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.66015625
# value + eps: 0.05098039656877518
# position x2 + eps 409.3346862792969
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.6640625
# value + eps: 0.05098039656877518
# position x2 + eps 409.33074951171875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.66796875
# value + eps: 0.05098039656877518
# position x2 + eps 409.3268127441406
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.671875
# value + eps: 0.05098039656877518
# position x2 + eps 409.3228759765625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.67578125
# value + eps: 0.05098039656877518
# position x2 + eps 409.3189392089844
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.6796875
# value + eps: 0.05098039656877518
# position x2 + eps 409.31500244140625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.68359375
# value + eps: 0.05098039656877518
# position x2 + eps 409.3110656738281
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.6875
# value + eps: 0.05098039656877518
# position x2 + eps 409.30712890625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.69140625
# value + eps: 0.05098039656877518
# position x2 + eps 409.3031921386719
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.6953125
# value + eps: 0.05098039656877518
# position x2 + eps 409.29925537109375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.69921875
# value + eps: 0.05098039656877518
# position x2 + eps 409.2953186035156
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.703125
# value + eps: 0.05098039656877518
# position x2 + eps 409.2913818359375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.70703125
# value + eps: 0.05098039656877518
# position x2 + eps 409.2874450683594
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.7109375
# value + eps: 0.05098039656877518
# position x2 + eps 409.28350830078125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.71484375
# value + eps: 0.05098039656877518
# position x2 + eps 409.2795715332031
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.71875
# value + eps: 0.05098039656877518
# position x2 + eps 409.275634765625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.72265625
# value + eps: 0.05098039656877518
# position x2 + eps 409.2716979980469
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.7265625
# value + eps: 0.05098039656877518
# position x2 + eps 409.26776123046875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.73046875
# value + eps: 0.05098039656877518
# position x2 + eps 409.2638244628906
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.734375
# value + eps: 0.05098039656877518
# position x2 + eps 409.2598876953125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.73828125
# value + eps: 0.05098039656877518
# position x2 + eps 409.2559509277344
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.7421875
# value + eps: 0.05098039656877518
# position x2 + eps 409.25201416015625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.74609375
# value + eps: 0.05098039656877518
# position x2 + eps 409.2480773925781
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.75
# value + eps: 0.05098039656877518
# position x2 + eps 409.244140625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.75390625
# value + eps: 0.05098039656877518
# position x2 + eps 409.2402038574219
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.7578125
# value + eps: 0.05098039656877518
# position x2 + eps 409.23626708984375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.76171875
# value + eps: 0.05098039656877518
# position x2 + eps 409.2323303222656
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.765625
# value + eps: 0.05098039656877518
# position x2 + eps 409.2283935546875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.76953125
# value + eps: 0.05098039656877518
# position x2 + eps 409.2244567871094
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.7734375
# value + eps: 0.05098039656877518
# position x2 + eps 409.22052001953125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.77734375
# value + eps: 0.05098039656877518
# position x2 + eps 409.2165832519531
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.78125
# value + eps: 0.05098039656877518
# position x2 + eps 409.212646484375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.78515625
# value + eps: 0.05098039656877518
# position x2 + eps 409.2087097167969
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.7890625
# value + eps: 0.05098039656877518
# position x2 + eps 409.20477294921875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.79296875
# value + eps: 0.05098039656877518
# position x2 + eps 409.2008361816406
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.796875
# value + eps: 0.05098039656877518
# position x2 + eps 409.1968994140625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.80078125
# value + eps: 0.05098039656877518
# position x2 + eps 409.1929626464844
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.8046875
# value + eps: 0.05098039656877518
# position x2 + eps 409.18902587890625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.80859375
# value + eps: 0.05098039656877518
# position x2 + eps 409.1850891113281
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.8125
# value + eps: 0.05098039656877518
# position x2 + eps 409.18115234375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.81640625
# value + eps: 0.05098039656877518
# position x2 + eps 409.1772155761719
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.8203125
# value + eps: 0.05098039656877518
# position x2 + eps 409.17327880859375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.82421875
# value + eps: 0.05098039656877518
# position x2 + eps 409.1693420410156
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.828125
# value + eps: 0.05098039656877518
# position x2 + eps 409.1654052734375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.83203125
# value + eps: 0.05098039656877518
# position x2 + eps 409.1614685058594
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.8359375
# value + eps: 0.05098039656877518
# position x2 + eps 409.15753173828125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.83984375
# value + eps: 0.05098039656877518
# position x2 + eps 409.1535949707031
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.84375
# value + eps: 0.05098039656877518
# position x2 + eps 409.149658203125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.84765625
# value + eps: 0.05098039656877518
# position x2 + eps 409.1457214355469
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.8515625
# value + eps: 0.05098039656877518
# position x2 + eps 409.14178466796875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.85546875
# value + eps: 0.05098039656877518
# position x2 + eps 409.1378479003906
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.859375
# value + eps: 0.05098039656877518
# position x2 + eps 409.1339111328125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.86328125
# value + eps: 0.05098039656877518
# position x2 + eps 409.1299743652344
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.8671875
# value + eps: 0.05098039656877518
# position x2 + eps 409.12603759765625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.87109375
# value + eps: 0.05098039656877518
# position x2 + eps 409.1221008300781
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.875
# value + eps: 0.05098039656877518
# position x2 + eps 409.1181640625
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.87890625
# value + eps: 0.05098039656877518
# position x2 + eps 409.1142272949219
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.8828125
# value + eps: 0.05098039656877518
# position x2 + eps 409.11029052734375
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.88671875
# value + eps: 0.05098039656877518
# position x2 + eps 409.1063537597656
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.890625
# value + eps: 0.05098039656877518
# position x2 + eps 409.1024169921875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.89453125
# value + eps: 0.05098039656877518
# position x2 + eps 409.0984802246094
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.8984375
# value + eps: 0.05098039656877518
# position x2 + eps 409.09454345703125
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.90234375
# value + eps: 0.05098039656877518
# position x2 + eps 409.0906066894531
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# Position x1 + eps 910.90625
# value + eps: 0.05098039656877518
# position x2 + eps 409.086669921875
# value x2 + eps 0.05882353335618973
# tensor(0.0549, grad_fn=<AutogradFnBackward>) tensor([-0.0004,  0.0004])
# ...
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7835998535156
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7796630859375
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7757263183594
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.77178955078125
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7678527832031
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.763916015625
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7599792480469
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.75604248046875
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7521057128906
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7481689453125
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7442321777344
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.74029541015625
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7363586425781
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.732421875
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7284851074219
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.72454833984375
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7206115722656
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7166748046875
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7127380371094
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.70880126953125
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.7048645019531
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.700927734375
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6969909667969
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.69305419921875
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6891174316406
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6851806640625
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6812438964844
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.67730712890625
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6733703613281
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.66943359375
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6654968261719
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.66156005859375
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6576232910156
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6536865234375
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6497497558594
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.64581298828125
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6418762207031
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.637939453125
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6340026855469
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.63006591796875
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6261291503906
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6221923828125
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6182556152344
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.61431884765625
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6103820800781
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6064453125
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.6025085449219
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.59857177734375
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5946350097656
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5906982421875
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5867614746094
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.58282470703125
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5788879394531
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.574951171875
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5710144042969
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.56707763671875
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5631408691406
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5592041015625
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5552673339844
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.55133056640625
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5473937988281
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.54345703125
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5395202636719
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.53558349609375
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5316467285156
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5277099609375
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5237731933594
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.51983642578125
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5158996582031
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.511962890625
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5080261230469
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.50408935546875
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.5001525878906
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.4962158203125
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# Position x1 + eps 912.50390625
# value + eps: 0.05098039656877518
# position x2 + eps 407.4922790527344
# value x2 + eps 0.05490196496248245
# tensor(0.0510, grad_fn=<AutogradFnBackward>) tensor([0.0000, 0.0004])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 19
#      15 end = (round(loc.grad[0].item() * 100000) + round(loc[0].item()),  round(loc.grad[1].item()* 100000) + round(loc[1].item()))
#      17 cv2.line(vis, start, end, [0, 255, 0], 2)
# ---> 19 cv2.imshow('Progress', vis)
#      20 cv2.waitKey(50)  # 20 fps, tune according to your liking
#      22 if loc.grad[0].item() == 0. and loc.grad[1].item() == 0.:
#
# KeyboardInterrupt:
